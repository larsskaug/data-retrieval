# %%
from webscrape_utils import read_credentials
import os
import json
import boto3
import pandas as pd
from multiprocessing import Pool

def initialize_worker(credentials_file, bucket_name):
    global s3_client, bucket
    home_directory = os.path.expanduser('~')
    credentials = read_credentials(os.path.join(home_directory, credentials_file))
    session = boto3.Session(
        aws_access_key_id=credentials['AWS_ACCESS_KEY_ID'],
        aws_secret_access_key=credentials['AWS_SECRET_ACCESS_KEY'],
        region_name=credentials['AWS_DEFAULT_REGION']
    )
    s3_client = session.client('s3')
    bucket = bucket_name

def fetch_object_from_s3(key):
    try:
        file_obj = s3_client.get_object(Bucket=bucket, Key=key)
        file_content = file_obj['Body'].read().decode('utf-8')
        return json.loads(file_content)
    except Exception as e:
        print(f"Error fetching {key}: {e}")
        return None

def fetch_jsons_from_s3(credentials_file, bucket_name, prefix, num_processes=16):
    home_directory = os.path.expanduser('~')
    credentials = read_credentials(os.path.join(home_directory, credentials_file))
    session = boto3.Session(
        aws_access_key_id=credentials['AWS_ACCESS_KEY_ID'],
        aws_secret_access_key=credentials['AWS_SECRET_ACCESS_KEY'],
        region_name=credentials['AWS_DEFAULT_REGION']
    )
    s3 = session.client('s3')
    
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)
    keys = [obj['Key'] for obj in response['Contents'] if obj['Key'].endswith('.json')]
    
    with Pool(processes=num_processes, initializer=initialize_worker, 
              initargs=(credentials_file, bucket_name)) as pool:
        all_data = pool.map(fetch_object_from_s3, keys)
    
    all_data = [data for data in all_data if data is not None]
    return pd.DataFrame(all_data)

def save_to_jsonl(dataframe, output_file):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    with open(output_file, 'w') as f:
        for _, record in dataframe.iterrows():
            f.write(json.dumps(record.to_dict()) + '\n')
    print(f"Data saved to {output_file}")

# Main
credentials_file = "credentials/aws.credentials"
bucket_name = 'prices-for-inflation-estimation'
prefix = 'inflation/'

dataframe = fetch_jsons_from_s3(credentials_file, bucket_name, prefix)
output_file = 'data/inflation_argentina_bigmac_and_yerba_mate.jsonl'
save_to_jsonl(dataframe, output_file)
# Out:
# Data saved to data/inflation_argentina_bigmac_and_yerba_mate.jsonl

# %%
import altair as alt
import pandas as pd
import json

def read_jsonl(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            data.append(json.loads(line))
    return pd.DataFrame(data)

def plot_price_over_time(df, product_name, line_color='steelblue'):
    df['ts'] = pd.to_datetime(df['ts'])
    filtered_data = df[df['product'] == product_name].sort_values('ts')
    filtered_data['price'] = pd.to_numeric(filtered_data['price'], errors='coerce')
    
    # Compute tick values every 500
    max_price = int(filtered_data['price'].max())
    tick_values = list(range(0, max_price + 500, 500))
    
    base = alt.Chart(filtered_data).encode(
        x='ts:T',
        tooltip=['ts:T', 'price:Q']
    ).properties(
        title=f'{product_name} Price Over Time',
        width=900,
        height=400
    )
    
    price_line = base.mark_line(strokeWidth=6, color=line_color).encode(
        y=alt.Y(
            'price:Q',
            title='Price (ARS)',
            axis=alt.Axis(orient='right', values=tick_values, grid=True)
        )
    )
    
    return price_line

# Load and process data
df = read_jsonl('data/inflation_argentina_bigmac_and_yerba_mate.jsonl')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Create charts
big_mac_chart = plot_price_over_time(df, 'Big Mac')
yerba_mate_chart = plot_price_over_time(df, 'yerba mate', 'green')

# Display charts
alt.vconcat(yerba_mate_chart).show()
# Out:
# alt.VConcatChart(...)

# %%
from webscrape_utils import read_credentials
import os
import json
import boto3
import pandas as pd
from multiprocessing import Pool

def initialize_worker(credentials_file, bucket_name):
    global s3_client, bucket
    home_directory = os.path.expanduser('~')
    credentials = read_credentials(os.path.join(home_directory, credentials_file))
    session = boto3.Session(
        aws_access_key_id=credentials['AWS_ACCESS_KEY_ID'],
        aws_secret_access_key=credentials['AWS_SECRET_ACCESS_KEY'],
        region_name=credentials['AWS_DEFAULT_REGION']
    )
    s3_client = session.client('s3')
    bucket = bucket_name

def fetch_object_from_s3(key):
    try:
        file_obj = s3_client.get_object(Bucket=bucket, Key=key)
        file_content = file_obj['Body'].read().decode('utf-8')
        return json.loads(file_content)
    except Exception as e:
        print(f"Error fetching {key}: {e}")
        return None

def fetch_jsons_from_s3(credentials_file, bucket_name, prefix, num_processes=16):
    home_directory = os.path.expanduser('~')
    credentials = read_credentials(os.path.join(home_directory, credentials_file))
    session = boto3.Session(
        aws_access_key_id=credentials['AWS_ACCESS_KEY_ID'],
        aws_secret_access_key=credentials['AWS_SECRET_ACCESS_KEY'],
        region_name=credentials['AWS_DEFAULT_REGION']
    )
    s3 = session.client('s3')
    
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)
    keys = [obj['Key'] for obj in response['Contents'] if obj['Key'].endswith('.json')]
    
    with Pool(processes=num_processes, initializer=initialize_worker, 
              initargs=(credentials_file, bucket_name)) as pool:
        all_data = pool.map(fetch_object_from_s3, keys)
    
    all_data = [data for data in all_data if data is not None]
    return pd.DataFrame(all_data)

def save_to_jsonl(dataframe, output_file):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    with open(output_file, 'w') as f:
        for _, record in dataframe.iterrows():
            f.write(json.dumps(record.to_dict()) + '\n')
    print(f"Data saved to {output_file}")

# Main
credentials_file = "credentials/aws.credentials"
bucket_name = 'prices-for-inflation-estimation'
prefix = 'inflation/'

dataframe = fetch_jsons_from_s3(credentials_file, bucket_name, prefix)
output_file = 'data/inflation_argentina_bigmac_and_yerba_mate.jsonl'
save_to_jsonl(dataframe, output_file)
